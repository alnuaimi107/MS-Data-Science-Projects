# %% [markdown]
# ## Nomadlist records

# %%
#!pip install selenium

# %%
profiles = 'https://nomadlist.com/@jackelynmossman'
idx = [a for a in range (1,255)]

# %%
import time
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.chrome.options import Options
options = Options()
options.add_argument('--headless')

ids = []
DRIVER_PATH = '/usr/local/bin/chromedriver'
driver = webdriver.Chrome(executable_path=DRIVER_PATH,options = options)
driver.get(profiles)
time.sleep(10)
# h1 = driver.find_element_by_class_name('most-overlaps')
for i in idx:
    user = driver.find_element_by_xpath("//div[@id='most-overlaps']/div[1]/a"+str([i])).get_attribute('href')
    ids.append(user)
driver.quit()

# %%
ids
# Out:
# ['https://nomadlist.com/@nomadtax',
#  'https://nomadlist.com/@imshashank',
#  'https://nomadlist.com/@mcma9',
#  'https://nomadlist.com/@dannybooboo',
#  'https://nomadlist.com/@juwe',
#  'https://nomadlist.com/@samlepak',
#  'https://nomadlist.com/@laird_evan',
#  'https://nomadlist.com/@klneptunas',
#  'https://nomadlist.com/@rolilink',
#  'https://nomadlist.com/@moloneymb',
#  'https://nomadlist.com/@travelingpuns',
#  'https://nomadlist.com/@maximus',
#  'https://nomadlist.com/@ryannelson',
#  'https://nomadlist.com/@nick_madaffari',
#  'https://nomadlist.com/@meeshcarra',
#  'https://nomadlist.com/@bountyhunter44',
#  'https://nomadlist.com/@mattj',
#  'https://nomadlist.com/@martinrdw',
#  'https://nomadlist.com/@stevecvar',
#  'https://nomadlist.com/@marcos',
#  'https://nomadlist.com/@matthewhallca',
#  'https://nomadlist.com/@julesmonroe',
#  'https://nomadlist.com/@danthehammerman',
#  'https://nomadlist.com/@zachandsumary',
#  'https://nomadlist.com/@eric_chambers',
# ...

# %%
import time
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.chrome.options import Options
options = Options()
options.add_argument('--headless')

data_dict = dict()
cities = []
countries = []

DRIVER_PATH = '/usr/local/bin/chromedriver'
driver = webdriver.Chrome(executable_path=DRIVER_PATH,options= options)
driver.get('https://nomadlist.com/@dannybooboo')
time.sleep(10)


# driver.find_element_by_xpath("//table[1]/tbody/tr[62]/td/div").click()
driver.find_element_by_xpath("(//div[contains(text(),'Expand all')])[1]").click()

time.sleep(3)

item_list_new = []
# print(driver.find_element_by_xpath("//tbody/tr"+str([i+j])+"/td[@class='name']/h2").text)
name = driver.find_element_by_xpath("/html/body/div[10]/div[2]/h1").text
print(name)
place = driver.find_elements_by_xpath("//tbody/tr/td[@class='name']/h2")
cnt = driver.find_elements_by_xpath("//tbody/tr/td[@class='country']")
cities = [x.text for x in place]
country = [y.text for y in cnt]
final = list(map(lambda x, y: x+ ',' +y, cities, country))
data_dict[name] = final

driver.quit()
# items
# country
# name
data_dict
# Out:
# @dannybooboo
# {'@dannybooboo': ['Medellín,Colombia',
#   'Mexico City,Mexico',
#   'Monterrey,Mexico',
#   'Playa del Carmen,Mexico',
#   'Medellín,Colombia',
#   'San Andrés,Colombia',
#   'Medellín,Colombia',
#   'Cúcuta,Colombia',
#   'Medellín,Colombia',
#   'São Paulo,Brazil',
#   'Istanbul,Turkey',
#   'Jakarta,Indonesia',
#   'Canggu, Bali,Indonesia',
#   'Ubud, Bali,Indonesia',
#   'Quezon City,Philippines',
#   'Hanoi,Vietnam',
#   'Nha Trang,Vietnam',
#   'Ho Chi Minh City,Vietnam',
#   'Chiang Mai,Thailand',
#   'San Francisco, CA,United States',
#   'Miami, FL,United States',
#   'Medellín,Colombia',
#   'Barranquilla,Colombia',
#   'Medellín,Colombia',
#   'Montevideo,Uruguay',
#   'Buenos Aires,Argentina',
#   'Rio de Janeiro,Brazil',
#   'Medellín,Colombia',
#   'Kyiv,Ukraine',
#   'Moscow,Russia',
#   'Almaty,Kazakhstan',
#   'Tbilisi,Georgia',
#   'Dubai,United Arab Emirates',
#   'Mumbai,India',
#   'Canggu, Bali,Indonesia',
#   'Sahaja Sawah Resort,Indonesia',
# ...

# %%
data_dict = dict()

# %%
import time
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
# from selenium.webdriver.chrome.options import Options
# options = Options()
# options.add_argument('--headless')

# data_dict = dict()
cities = []
countries = []

DRIVER_PATH = '/usr/local/bin/chromedriver'
driver = webdriver.Chrome(executable_path=DRIVER_PATH)#,options= options)
    
for i in ids[256:261]:
    print(i)
    driver.get(i)

    try:
        time.sleep(7)
#         driver.find_element_by_xpath("//div[contains(text(),'Expand all')]").click()
# //tr[contains(@*,'tr-expand-all-trips')]/td/div
        driver.find_element_by_xpath("//tr[contains(@*,'tr-expand-all-trips')]/td/div").click()
        time.sleep(2)

        name = driver.find_element_by_xpath("/html/body/div[10]/div[2]/h1").text
        print(name)
#         place = driver.find_elements_by_xpath("//tbody/tr/td[@class='name']/h2")
        place = driver.find_elements_by_xpath("//td[contains(@class,'name')]/h2")
        time.sleep(3)

#         cnt = driver.find_elements_by_xpath("//tbody/tr/td[@class='country']")
        cnt = driver.find_elements_by_xpath("//td[contains(@class,'country')]")
        time.sleep(3)

        city = [x.text for x in place]
        print(city)
        country = [y.text for y in cnt]
        print(country)
        final = list(zip(city,country))
        data_dict[name] = final
        time.sleep(5)
    except:
        time.sleep(3)
        name = driver.find_element_by_xpath("/html/body/div[10]/div[2]/h1").text
        print(name)

#         place = driver.find_elements_by_xpath("//tbody/tr/td[@class='name']/h2")
        place = driver.find_elements_by_xpath("//td[contains(@class,'name')]/h2")
        time.sleep(3)
#         cnt = driver.find_elements_by_xpath("//tbody/tr/td[@class='country']")
        cnt = driver.find_elements_by_xpath("//td[contains(@class,'country')]")
        time.sleep(3)
        city = [x.text for x in place]
        print(city)
        country = [y.text for y in cnt]
        print(country)
        final = list(zip(city,country))
        data_dict[name] = final
        time.sleep(5)
    finally:
        continue

driver.quit()

# %%
len(data_dict)
# Out:
# 227

# %%
data_dict
# Out:
# {'@nomadtax': [('Cape Town', 'South Africa'),
#   ('Sarandë', 'Albania'),
#   ('Cairo', 'Egypt'),
#   ('Gran Canaria', 'Spain'),
#   ('Sarandë', 'Albania'),
#   ('Marseille', 'France'),
#   ('Sarandë', 'Albania'),
#   ('Tirana', 'Albania'),
#   ('Bansko', 'Bulgaria'),
#   ('Belgrade', 'Serbia'),
#   ('Skopje', 'North Macedonia'),
#   ('Pristina', 'Kosovo'),
#   ('Prizren', 'Kosovo'),
#   ('Tirana', 'Albania'),
#   ('Vlorë', 'Albania'),
#   ('Ohrid', 'North Macedonia'),
#   ('Meteora', 'Greece'),
#   ('Bansko', 'Bulgaria'),
#   ('Milan', 'Italy'),
#   ('Basel', 'Switzerland'),
#   ('Palermo', 'Italy'),
#   ('Frankfurt', 'Germany'),
#   ('Kavala Airport Megas Alexandros', 'Greece'),
#   ('Bansko', 'Bulgaria'),
#   ('Playa del Carmen', 'Mexico'),
#   ('Memphis, TN', 'United States'),
#   ('Panama City', 'Panama'),
#   ('Playa del Carmen', 'Mexico'),
#   ('San Juan del Sur', 'Nicaragua'),
#   ('Playa del Carmen', 'Mexico'),
#   ('Merida', 'Mexico'),
# ...

# %% [markdown]
# ## Namelist creation

# %%
import time
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
# from selenium.webdriver.chrome.options import Options
# options = Options()
# options.add_argument('--headless')

# data_dict = dict()
cities = []
countries = []

DRIVER_PATH = '/usr/local/bin/chromedriver'
driver = webdriver.Chrome(executable_path=DRIVER_PATH)#,options= options)

# %%
len(data_dict)
# Out:
# 28

# %%
import pandas as pd
x = pd.DataFrame(data_dict.items()) 
x
# Out:
#                   0                                                  1
# 0         @nomadtax  [(Cape Town, South Africa), (Sarandë, Albania)...
# 1       @imshashank  [(Podgorica, Montenegro), (Sofia, Bulgaria), (...
# 2            @mcma9  [(Playa del Carmen, Mexico), (Playa del Carmen...
# 3      @dannybooboo  [(Medellín, Colombia), (Mexico City, Mexico), ...
# 4             @juwe  [(Saint Petersburg, Russia), (Irkutsk, Russia)...
# ..              ...                                                ...
# 222          @demin  [(Barcelona, Spain), (Istanbul, Turkey), (Batu...
# 223      @shadiosta  [(San Francisco, CA, United States), (Boston, ...
# 224  @polinakocheva  [(Phuket, Thailand), (Barcelona, Spain), (Sofi...
# 225          @kenny  [(Dallas, TX, United States), (San Diego, CA, ...
# 226        @d3young  [(Phuket, Thailand), (Cape Town, South Africa)...
#
# [227 rows x 2 columns]

# %%
x.to_csv('try2.csv')

# %% [markdown]
# ## New Trial V2.0

# %%
import pandas as pd
cols= ["users","places"]
df= pd.read_csv('try2.csv', names = cols)
df = df.iloc[1:]
df
# Out:
#                 users                                             places
# 0.0         @nomadtax  [('Cape Town', 'South Africa'), ('Sarandë', 'A...
# 1.0       @imshashank  [('Podgorica', 'Montenegro'), ('Sofia', 'Bulga...
# 2.0            @mcma9  [('Playa del Carmen', 'Mexico'), ('Playa del C...
# 3.0      @dannybooboo  [('Medellín', 'Colombia'), ('Mexico City', 'Me...
# 4.0             @juwe  [('Saint Petersburg', 'Russia'), ('Irkutsk', '...
# ...               ...                                                ...
# 222.0          @demin  [('Barcelona', 'Spain'), ('Istanbul', 'Turkey'...
# 223.0      @shadiosta  [('San Francisco, CA', 'United States'), ('Bos...
# 224.0  @polinakocheva  [('Phuket', 'Thailand'), ('Barcelona', 'Spain'...
# 225.0          @kenny  [('Dallas, TX', 'United States'), ('San Diego,...
# 226.0        @d3young  [('Phuket', 'Thailand'), ('Cape Town', 'South ...
#
# [227 rows x 2 columns]

# %%
d_dict = df.set_index('users').T.to_dict('list')
d_dict
# Out:
# {'@nomadtax': ["[('Cape Town', 'South Africa'), ('Sarandë', 'Albania'), ('Cairo', 'Egypt'), ('Gran Canaria', 'Spain'), ('Sarandë', 'Albania'), ('Marseille', 'France'), ('Sarandë', 'Albania'), ('Tirana', 'Albania'), ('Bansko', 'Bulgaria'), ('Belgrade', 'Serbia'), ('Skopje', 'North Macedonia'), ('Pristina', 'Kosovo'), ('Prizren', 'Kosovo'), ('Tirana', 'Albania'), ('Vlorë', 'Albania'), ('Ohrid', 'North Macedonia'), ('Meteora', 'Greece'), ('Bansko', 'Bulgaria'), ('Milan', 'Italy'), ('Basel', 'Switzerland'), ('Palermo', 'Italy'), ('Frankfurt', 'Germany'), ('Kavala Airport Megas Alexandros', 'Greece'), ('Bansko', 'Bulgaria'), ('Playa del Carmen', 'Mexico'), ('Memphis, TN', 'United States'), ('Panama City', 'Panama'), ('Playa del Carmen', 'Mexico'), ('San Juan del Sur', 'Nicaragua'), ('Playa del Carmen', 'Mexico'), ('Merida', 'Mexico'), ('Birmingham, AL', 'United States'), ('Oaxaca', 'Mexico'), ('Merida', 'Mexico'), ('Memphis, TN', 'United States'), ('Guatemala City', 'Guatemala'), ('San Ma
# ...

# %%
# new_dict = dict()
# for j in d_dict.values():
#     print(j[0])

# %% [markdown]
# ## TR3.0

# %%
profiles = 'https://nomadlist.com/@jackelynmossman'
idx = [a for a in range (1,255)]

# %%
import time
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.chrome.options import Options
options = Options()
options.add_argument('--headless')

ids = []
DRIVER_PATH = '/usr/local/bin/chromedriver'
driver = webdriver.Chrome(executable_path=DRIVER_PATH,options = options)
driver.get(profiles)
time.sleep(10)
# h1 = driver.find_element_by_class_name('most-overlaps')
for i in idx:
    user = driver.find_element_by_xpath("//div[@id='most-overlaps']/div[1]/a"+str([i])).get_attribute('href')
    ids.append(user)
driver.quit()

# %%
len(ids)
# Out:
# 254

# %%
# data_dict = dict()
users = []
places = []

# %%
import time
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
# from selenium.webdriver.chrome.options import Options
# options = Options()
# options.add_argument('--headless')

# data_dict = dict()
cities = []
countries = []

DRIVER_PATH = '/usr/local/bin/chromedriver'
driver = webdriver.Chrome(executable_path=DRIVER_PATH)#,options= options)
    
for i in ids[35:45]:
    print(i)
    driver.get(i)

    try:
        time.sleep(7)
        driver.find_element_by_xpath("//tr[contains(@*,'tr-expand-all-trips')]/td/div").click()
        time.sleep(2)

        name = driver.find_element_by_xpath("/html/body/div[10]/div[2]/h1").text
        print(name)
#         place = driver.find_elements_by_xpath("//tbody/tr/td[@class='name']/h2")
        place = driver.find_elements_by_xpath("//td[contains(@class,'name')]/h2")
        time.sleep(3)

#         cnt = driver.find_elements_by_xpath("//tbody/tr/td[@class='country']")
#         cnt = driver.find_elements_by_xpath("//td[contains(@class,'country')]")
#         time.sleep(3)

        city = [x.text for x in place]
        print(city)
#         country = [y.text for y in cnt]
#         print(country)
#         final = list(zip(city,country))
        for j in city:
            users.append(name)
            places.append(j)
        time.sleep(5)
    except:
        time.sleep(3)
        name = driver.find_element_by_xpath("/html/body/div[10]/div[2]/h1").text
        print(name)

#         place = driver.find_elements_by_xpath("//tbody/tr/td[@class='name']/h2")
        place = driver.find_elements_by_xpath("//td[contains(@class,'name')]/h2")
        time.sleep(3)
#         cnt = driver.find_elements_by_xpath("//tbody/tr/td[@class='country']")
#         cnt = driver.find_elements_by_xpath("//td[contains(@class,'country')]")
#         time.sleep(3)
        city = [x.text for x in place]
        print(city)
#         country = [y.text for y in cnt]
#         print(country)
#         final = list(zip(city,country))
#         data_dict[name] = final
        for j in city:
            users.append(name)
            places.append(j)
        time.sleep(5)
    finally:
        continue

driver.quit()
# Out:
# https://nomadlist.com/@camper
# @camper
# ['Cartagena']
# https://nomadlist.com/@cold
# @cold
# ['Florence', 'Hoi An', 'Chiang Mai', 'Vancouver', 'Mumbai', 'San Francisco, CA', 'Berkeley']
# https://nomadlist.com/@boris_k
# @boris_k
# ...

# %%
len(users)
# Out:
# 718

# %%
len(places)
# Out:
# 1995

# %%
import pandas as pd
nomads = pd.DataFrame()
nomads['users'] = users
nomads['places'] = places
nomads.head()
# Out:
#        users        places
# 0  @nomadtax     Cape Town
# 1  @nomadtax        Tirana
# 2  @nomadtax       Sarandë
# 3  @nomadtax         Cairo
# 4  @nomadtax  Gran Canaria

# %%
nomads.to_csv('nom_list.csv')
